# %% [markdown]
# Code #1

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, r2_score, mean_absolute_error
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv('student-scores.csv')
data.fillna(0, inplace=True)
# print(data.columns)

df = pd.DataFrame(data)
# print(df.head())

le = LabelEncoder()
# we can also use mapping instead of label encoding
# df['part_time_job'] = df['part_time_job'].map({'yes': 1, 'no': 0})    #  Dict can also be used for mapping
df['part_time_job'] = le.fit_transform(df['part_time_job'])     # label endoding (le)
df['extracurricular_activities'] = le.fit_transform(df['extracurricular_activities'])     # label endoding (le)
# print(df['part_time_job'])    # works fine

# Feature selection
X = df[['weekly_self_study_hours', 'absence_days', 'part_time_job', 'extracurricular_activities']]
y = df['total_score']
# X, y

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
# print(y_pred)

# %%
X_train.isnull().sum()
# Out:
# weekly_self_study_hours       0
# absence_days                  0
# part_time_job                 0
# extracurricular_activities    0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Clear, simple plots without seaborn
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error, classification_report, confusion_matrix

# Metrics on test set
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
cm = confusion_matrix(y_test, np.round(y_pred))
report = classification_report(y_test, np.round(y_pred))

weekly_med = df['weekly_self_study_hours'].median()
absence_med = df['absence_days'].median()
part_mode = int(df['part_time_job'].mode()[0])

# print(cm)
# print(report)
print(f"R2 Score: {r2}")
print(f"Mean Absolute Error: {mae}")
# Out:
# R2 Score: 0.26893647698317835
# Mean Absolute Error: 29.750997095920347
# C:\Users\Saad\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\Saad\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %%
# new_pred = model.predict([[5, 8, 1]])
# print(new_pred)

# new_pred = model.predict([[32, 4, 0]])
# print(new_pred)
